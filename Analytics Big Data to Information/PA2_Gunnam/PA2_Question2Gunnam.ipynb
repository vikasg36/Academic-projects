# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
run = pd.read_csv("input/fossil-fuel-co2-emissions-by-nation_filtered.csv")
run.dtypes
# Out:
# Year                             int64
# Country                         object
# Total                            int64
# Solid Fuel                       int64
# Liquid Fuel                      int64
# Gas Fuel                         int64
# Cement                           int64
# Gas Flaring                      int64
# Per Capita                     float64
# Bunker fuels (Not in Total)      int64
# dtype: object

# %%
run.Country
# Out:
# 0                      AFGHANISTAN
# 1                          ALBANIA
# 2                          ALGERIA
# 3                           ANGOLA
# 4                        ARGENTINA
#                    ...
# 12457                     VIET NAM
# 12458    WALLIS AND FUTUNA ISLANDS
# 12459                        YEMEN
# 12460                       ZAMBIA
# 12461                     ZIMBABWE
# Name: Country, Length: 12462, dtype: object

# %%
final = run[run['Country']=='UNITED STATES OF AMERICA']
final
# Out:
#        Year                   Country    Total  Solid Fuel  Liquid Fuel  \
# 143    1950  UNITED STATES OF AMERICA   692124      343131       244760
# 294    1951  UNITED STATES OF AMERICA   712983      330676       262189
# 447    1952  UNITED STATES OF AMERICA   694618      293170       273190
# 600    1953  UNITED STATES OF AMERICA   711175      290927       286594
# 754    1954  UNITED STATES OF AMERICA   677689      249303       290178
# ...     ...                       ...      ...         ...          ...
# 11575  2010  UNITED STATES OF AMERICA  1471375      521330       590751
# 11792  2011  UNITED STATES OF AMERICA  1442509      498720       575746
# 12012  2012  UNITED STATES OF AMERICA  1396083      443904       566582
# 12232  2013  UNITED STATES OF AMERICA  1406916      450641       562260
# 12452  2014  UNITED STATES OF AMERICA  1432855      450047       576531
#
#        Gas Fuel  Cement  Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# ...

# %%
final1 = final[final.Year > 1949]
final1
# Out:
#        Year                   Country    Total  Solid Fuel  Liquid Fuel  \
# 143    1950  UNITED STATES OF AMERICA   692124      343131       244760
# 294    1951  UNITED STATES OF AMERICA   712983      330676       262189
# 447    1952  UNITED STATES OF AMERICA   694618      293170       273190
# 600    1953  UNITED STATES OF AMERICA   711175      290927       286594
# 754    1954  UNITED STATES OF AMERICA   677689      249303       290178
# ...     ...                       ...      ...         ...          ...
# 11575  2010  UNITED STATES OF AMERICA  1471375      521330       590751
# 11792  2011  UNITED STATES OF AMERICA  1442509      498720       575746
# 12012  2012  UNITED STATES OF AMERICA  1396083      443904       566582
# 12232  2013  UNITED STATES OF AMERICA  1406916      450641       562260
# 12452  2014  UNITED STATES OF AMERICA  1432855      450047       576531
#
#        Gas Fuel  Cement  Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# ...

# %%
base = alt.Chart(df11.reset_index()).encode(x='Year')
selection = alt.selection_multi(fields = fi, bind = 'legend')
alt.layer(
    base.mark_line(color='pink').encode(y='Total'),
    base.mark_line(color='indigo').encode(y='Solid Fuel'),
    base.mark_line(color='purple').encode(y='Liquid Fuel'),
    base.mark_line(color='white').encode(y='Gas Fuel'),
    base.mark_line(color='yellow').encode(y='Cement'),
    base.mark_line(color='green').encode(y='Gas Flaring'),
    base.mark_line(color='red').encode(y='Per Capita'),
    base.mark_line(color='blue').encode(y='Bunker fuels (Not in Total)')
)
# Out:
# alt.LayerChart(...)

# %%
final2 = run[run.Country.str.contains('UNITED STATES') | run.Country.str.contains('SPAIN')| run.Country.str.contains('BHUTAN')| run.Country.str.contains('ARGENTINA')| run.Country.str.contains('ALGERIA')| run.Country.str.contains('INDIA')| run.Country.str.contains('ITALY')| run.Country.str.contains('FRANCE')| run.Country.str.contains('BRAZIL')| run.Country.str.contains('JAPAN')]
final2
# Out:
#        Year                       Country    Total  Solid Fuel  Liquid Fuel  \
# 2      1950                       ALGERIA     1033         514          475
# 4      1950                     ARGENTINA     8168         972         6982
# 13     1950                        BRAZIL     5367        1742         3433
# 46     1950     FRANCE (INCLUDING MONACO)    55215       45537         8575
# 66     1950                         INDIA    18178       15855         1962
# ...     ...                           ...      ...         ...          ...
# 12333  2014                         INDIA   610411      407077       140199
# 12339  2014  ITALY (INCLUDING SAN MARINO)    87377       13532        39265
# 12341  2014                         JAPAN   331074      122461       133395
# 12425  2014                         SPAIN    63806       11852        35189
# 12452  2014      UNITED STATES OF AMERICA  1432855      450047       576531
#
# ...

# %%
final2.Country.value_counts()
# Out:
# SPAIN                           65
# ARGENTINA                       65
# JAPAN                           65
# BRAZIL                          65
# FRANCE (INCLUDING MONACO)       65
# ITALY (INCLUDING SAN MARINO)    65
# UNITED STATES OF AMERICA        65
# ALGERIA                         65
# INDIA                           65
# BHUTAN                          45
# Name: Country, dtype: int64

# %%
alt.Chart(final2).mark_line().encode(
    x='Year',
    y='Total',
    color='Country',
    strokeDash='Country',
)
# Out:
# alt.Chart(...)

# %%
final3 = pd.read_csv("input/census_data_90.csv")
final3.dtypes
# Out:
# id           int64
# State       object
# TotalPop     int64
# Men          int64
# Women        int64
# dtype: object
